# %%
# Install packages
# !pip install kagglehub==0.4.0
# Out:
# Requirement already satisfied: kagglehub==0.4.0 in c:\users\daia prado\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in c:\users\daia prado\anaconda3\lib\site-packages (from kagglehub==0.4.0) (0.1.14)
# Requirement already satisfied: packaging in c:\users\daia prado\anaconda3\lib\site-packages (from kagglehub==0.4.0) (24.2)
# Requirement already satisfied: pyyaml in c:\users\daia prado\anaconda3\lib\site-packages (from kagglehub==0.4.0) (6.0.2)
# Requirement already satisfied: requests in c:\users\daia prado\anaconda3\lib\site-packages (from kagglehub==0.4.0) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\daia prado\anaconda3\lib\site-packages (from kagglehub==0.4.0) (4.67.1)
# Requirement already satisfied: protobuf in c:\users\daia prado\anaconda3\lib\site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub==0.4.0) (6.33.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\daia prado\anaconda3\lib\site-packages (from requests->kagglehub==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\daia prado\anaconda3\lib\site-packages (from requests->kagglehub==0.4.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\daia prado\anaconda3\lib\site-packages (from requests->kagglehub==0.4.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\daia prado\anaconda3\lib\site-packages (from requests->kagglehub==0.4.0) (2025.4.26)
# Requirement already satisfied: colorama in c:\users\daia prado\anaconda3\lib\site-packages (from tqdm->kagglehub==0.4.0) (0.4.6)

# %%
# Import libraries. 
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from scipy.stats import chi2_contingency

# %%
# Download latest version
path = kagglehub.dataset_download("yasserh/loan-default-dataset")

df = pd.read_csv(f"{path}/Loan_Default.csv")

# %%
# Dataset exploration
df.info()

cols_w_missing_v = df.columns[df.isnull().any()]
print()
print(f"Columns with missing values: {len(cols_w_missing_v)}{"\n"}{cols_w_missing_v}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
#  13  Upfront_charges            109028 non-null  float64
#  14  term                       148629 non-null  float64
#  15  Neg_ammortization          148549 non-null  object
#  16  interest_only              148670 non-null  object
#  17  lump_sum_payment           148670 non-null  object
#  18  property_value             133572 non-null  float64
#  19  construction_type          148670 non-null  object
#  20  occupancy_type             148670 non-null  object
#  21  Secured_by                 148670 non-null  object
#  22  total_units                148670 non-null  object
#  23  income                     139520 non-null  float64
#  24  credit_type                148670 non-null  object
#  25  Credit_Score               148670 non-null  int64
#  26  co-applicant_credit_type   148670 non-null  object
#  27  age                        148470 non-null  object
#  28  submission_of_application  148470 non-null  object
#  29  LTV                        133572 non-null  float64
#  30  Region                     148670 non-null  object
#  31  Security_Type              148670 non-null  object
#  32  Status                     148670 non-null  int64
#  33  dtir1                      124549 non-null  float64
# dtypes: float64(8), int64(5), object(21)
# memory usage: 38.6+ MB
#
# Columns with missing values: 14
# Index(['loan_limit', 'approv_in_adv', 'loan_purpose', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'Neg_ammortization',
#        'property_value', 'income', 'age', 'submission_of_application', 'LTV',
#        'dtir1'],
#       dtype='object')

# %%
# Counting missing values per column
def missing_data(dataframe): 
    return dataframe.isnull().sum()

missing_data(df)
# Out:
# ID                               0
# year                             0
# loan_limit                    3344
# Gender                           0
# approv_in_adv                  908
# loan_type                        0
# loan_purpose                   134
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             36439
# Interest_rate_spread         36639
# Upfront_charges              39642
# term                            41
# Neg_ammortization              121
# interest_only                    0
# lump_sum_payment                 0
# property_value               15098
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        9150
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# age                            200
# submission_of_application      200
# LTV                          15098
# Region                           0
# Security_Type                    0
# Status                           0
# dtir1                        24121
# dtype: int64

# %%
# check % of missing values. If a column has more than 50% of missing values, it will be eliminated. 
missing_values = pd.DataFrame(missing_data(df), columns=["missing_values"])
missing_values["missing_pct"] = missing_values/len(df)

cols_to_drop = missing_values[missing_values["missing_pct"] > 0.5].index
cols_to_drop

# No columns above 50% with missing data.
# Out:
# Index([], dtype='object')

# %%
# check for records that have more than 50% in nan and eliminate them if any. 
threshold = 0.5

rows_to_drop = df.isna().mean(axis=1) > threshold
df.loc[rows_to_drop==True].count().sum() # count for any that was above 0.5. 

# No records to eliminate
# Out:
# np.int64(0)

# %%
# Check for duplicates to minimize missing values.
df.duplicated().sum()

# No duplicates
# Out:
# np.int64(0)

# %%
# Obtain non numerical columns and extract unique values to get more insights for missing values treatment. 
non_num_cols = df.select_dtypes(exclude="number").columns
print("Non-numerical columns:", "\n", len(non_num_cols))

# Explore type of information in each column. For that let's print the unique values of each. 
for record in non_num_cols: 
    
    unique_values = df[record].unique()
    print("\n", record, ": ", unique_values)
# Out:
# Non-numerical columns:
#  21
#
#  loan_limit :  ['cf' nan 'ncf']
#
#  Gender :  ['Sex Not Available' 'Male' 'Joint' 'Female']
#
#  approv_in_adv :  ['nopre' 'pre' nan]
#
#  loan_type :  ['type1' 'type2' 'type3']
#
#  loan_purpose :  ['p1' 'p4' 'p3' 'p2' nan]
#
#  Credit_Worthiness :  ['l1' 'l2']
#
#  open_credit :  ['nopc' 'opc']
#
#  business_or_commercial :  ['nob/c' 'b/c']
#
#  Neg_ammortization :  ['not_neg' 'neg_amm' nan]
#
#  interest_only :  ['not_int' 'int_only']
#
#  lump_sum_payment :  ['not_lpsm' 'lpsm']
#
#  construction_type :  ['sb' 'mh']
#
#  occupancy_type :  ['pr' 'sr' 'ir']
#
#  Secured_by :  ['home' 'land']
#
#  total_units :  ['1U' '2U' '3U' '4U']
#
#  credit_type :  ['EXP' 'EQUI' 'CRIF' 'CIB']
#
#  co-applicant_credit_type :  ['CIB' 'EXP']
#
#  age :  ['25-34' '55-64' '35-44' '45-54' '65-74' '>74' '<25' nan]
#
#  submission_of_application :  ['to_inst' 'not_inst' nan]
#
#  Region :  ['south' 'North' 'central' 'North-East']
#
#  Security_Type :  ['direct' 'Indriect']

# %% [markdown]
# The columns with missing values are:
#
# |Coumns|Missing values|
# |------|-------------|
# |loan_limit                    |3344|
# |approv_in_adv                  |908|
# |loan_purpose                   |134|
# |rate_of_interest             |36439|
# |Interest_rate_spread         |36639|
# |Upfront_charges              |39642|
# |term                            |41|
# |Neg_ammortization              |121|
# |property_value               |15098|
# |income                        |9150|
# |age                            |200|
# |submission_of_application      |200|
# |LTV                          |15098|
# |dtir1                        |24121|
#
# Some highlights:
# - In banking the following are gold features, thus the nan values can not be eliminated, since they also give certain type of information. Based on research:
#
#   |Feature|Meaning|
#   |------|-------|
#   |"rate_of_interest"|not given one|
#   |"Interest_rate_spread"|derived from the rate_of_interest. Missing values to calculate|
#   |"Upfront_charges"|client with different product or not evaluated|
#   |"dtir1"| debt-to-income not calculated|
#
# - "property_value" means that the appraisal was not made.
# - LTV derivates from property_value. LTV is calculated as *loan_amount/property_value*, which means that if we don't have the property value, we can't calculate it. In banking LTV is highly interpretable for determining default. A high LTV means a higher default risk. The missing values, will be kept.
# - "income" means it wasn't declared
# - "submission_of_application" can not be determined by any other feature. The feature has 2 values, *to_inst* and *not_inst*. *not_inst* means that the solicitation was either incomplete, it was a pre-application, or the lead was not converted. Thus since the loan never started, this records will be deleted.
# - Features that could be imputable are: "loan_limit", "approv_in_adv", "loan_purpose", "term", "Neg_ammortization", "age", "submission_of_application"

# %%
# Delete records that were not a loan
df_loans = df.copy()
df_loans = df_loans[df_loans["submission_of_application"] != "not_inst"]

# check for missing data reduction
print(f"Columns with missing values: {(missing_data(df_loans) > 0).sum()}{"\n"}")
# no reduction of columns with missing data. 

missing_data(df_loans)
# Reduction of number of missing data
# Out:
# Columns with missing values: 14
# ID                               0
# year                             0
# loan_limit                    2118
# Gender                           0
# approv_in_adv                  661
# loan_type                        0
# loan_purpose                    65
# Credit_Worthiness                0
# open_credit                      0
# business_or_commercial           0
# loan_amount                      0
# rate_of_interest             27213
# Interest_rate_spread         27413
# Upfront_charges              29763
# term                            40
# Neg_ammortization               76
# interest_only                    0
# lump_sum_payment                 0
# property_value               10593
# construction_type                0
# occupancy_type                   0
# Secured_by                       0
# total_units                      0
# income                        5629
# credit_type                      0
# Credit_Score                     0
# co-applicant_credit_type         0
# age                            200
# submission_of_application      200
# LTV                          10593
# Region                           0
# Security_Type                    0
# Status                           0
# dtir1                        16098
# dtype: int64

# %%
# Since we want to try out different models (logistic regression and XGBoost), 
# it's important to create different datasets that can be handled by them. 
# Logistic regression = doesn't tolerate missing values and outliers
# XGBoost = tolearates missing values and outliers

df_na = df_loans.copy() # DF with native NA. No changes needed 

# Create the missing flags for the golden features and put the median in the nan values. 
df_no_na = df_loans.copy() # DF with no NA, but with missing flags and imputed values. 
missing_flags_cols = ["rate_of_interest", "Interest_rate_spread", 
                      "Upfront_charges", "dtir1", "property_value", 
                      "LTV", "income"]

for col in missing_flags_cols: 
    df_na[col+"_missing"] = df_na[col].isna().astype(int)
    df_no_na[col+"_missing"] = df_no_na[col].isna().astype(int)
    df_no_na[col] = df_no_na[col].fillna(df_no_na[col].median())

# Insert the median in numerical data. 
df_no_na["term"] = df_no_na[col].fillna(df_no_na[col].median())

# For categorical columns, fillna with an extra category called "Missing"
missing_val_cat_cols = ["loan_limit", "approv_in_adv", "loan_purpose", 
                        "Neg_ammortization", "submission_of_application", "age"]
for col in missing_val_cat_cols:
    df_no_na[col] = df_no_na[col].fillna("Missing")

# check for missing values again in the df_no_na df. 
missing_data(df_no_na)
# Out:
# ID                              0
# year                            0
# loan_limit                      0
# Gender                          0
# approv_in_adv                   0
# loan_type                       0
# loan_purpose                    0
# Credit_Worthiness               0
# open_credit                     0
# business_or_commercial          0
# loan_amount                     0
# rate_of_interest                0
# Interest_rate_spread            0
# Upfront_charges                 0
# term                            0
# Neg_ammortization               0
# interest_only                   0
# lump_sum_payment                0
# property_value                  0
# construction_type               0
# occupancy_type                  0
# Secured_by                      0
# total_units                     0
# income                          0
# credit_type                     0
# Credit_Score                    0
# co-applicant_credit_type        0
# age                             0
# submission_of_application       0
# LTV                             0
# Region                          0
# Security_Type                   0
# Status                          0
# dtir1                           0
# rate_of_interest_missing        0
# Interest_rate_spread_missing    0
# Upfront_charges_missing         0
# dtir1_missing                   0
# property_value_missing          0
# LTV_missing                     0
# income_missing                  0
# dtype: int64

# %%
# Check for outliers
# Extract numeric_columns
numeric_cols = df_no_na.select_dtypes(exclude="object")

# Eliminate non valuable columns (such as the ones with "_missing")
numeric_cols = list(numeric_cols.columns[~numeric_cols.columns.str.contains("missing")])
del numeric_cols[:2]

# Remove Status
numeric_cols.remove("Status")
numeric_cols

# Calculate IQR
def iqr_outliers(feature):
    q1 = feature.quantile(0.25)
    q3 = feature.quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    return lower, upper

# detect the outliers per column 
outlier_summary = {}
for col in numeric_cols: 
    f = df_no_na[col].dropna()
    lower, upper = iqr_outliers(f)

    n_outliers = ((f < lower) | (f > upper)).sum()
    outlier_summary[col] = {
        "lower": lower, 
        "upper": upper, 
        "n_outliers": n_outliers,
        "pct_outliers": round((n_outliers/len(f)*100), 2)
    }

possible_errors = []
rare_values = []
long_tales = []
subsamples = []

for key in outlier_summary.keys(): 
    if (outlier_summary[key]["pct_outliers"] < 0.5) and (outlier_summary[key]["pct_outliers"] != 0):
        possible_errors.append(key)
    elif (outlier_summary[key]["pct_outliers"] > 0.5) and (outlier_summary[key]["pct_outliers"] < 2): 
        rare_values.append(key)
    elif (outlier_summary[key]["pct_outliers"] > 2) and (outlier_summary[key]["pct_outliers"] < 10):
        long_tales.append(key)
    else:
        subsamples.append(key)

print(f"Possible features with errors {possible_errors}")
print(f"rare values {rare_values}")
print(f"long tale {long_tales}")
print(f"subsamples {subsamples}")
# Out:
# Possible features with errors []
# rare values []
# long tale ['loan_amount', 'rate_of_interest', 'Interest_rate_spread', 'term', 'property_value', 'income', 'LTV', 'dtir1']
# subsamples ['Upfront_charges', 'Credit_Score']

# %% [markdown]
# The Long tales will be the ones to watch out for a possible transformation.

# %%
# plot outliers
def plot_outliers(feature, v_df):
    for col in feature:
        plt.figure(figsize=(6,2))
        sns.boxplot(x=v_df[col])
        plt.title(col)
        plt.show()

plot_outliers(long_tales, df_no_na)

# %% [markdown]
# The outliers shown above are logical, although in some circunstances like LTV, income and term present some extreme values, they represent situations that can happen in real life with some exceptional clients. Thus such cases will not be eliminated, but transformed to:
# - Reduce asymmetry
# - smooth long tales
# - reduce extreme values impacts
# - improve model's stability
#
# However LTV, dtir1 and rate_of_interest, will be winsorized instead of transformed due to the fact that these metrics are ratios. If these are transformed the linear relationship between them and the risk would be broken, eliminating the insights of risk behavior.

# %%
tales_to_transform = ["loan_amount", "property_value", "income"]
tales_to_winsor = ["Interest_rate_spread", "LTV", "dtir1"]

for col in tales_to_transform:
    df_no_na[col] = np.log1p(df_no_na[col])

# plot to see the new ranges of outliers
plot_outliers(long_tales, df_no_na)

# %%
# Obtain correlations between features vs target. 
# add the status column again. 
numeric_cols.append("Status") # Run this line 1 time. 

# check for numerical correlations
corr = df_no_na[numeric_cols].corr(method="spearman")

# plot correlations
def plot_corr(matrix, title): 
    plt.figure(figsize=(7,5))
    sns.heatmap(matrix)
    plt.title(title)
    plt.show()

plot_corr(corr, "Numerical correlations")

# %% [markdown]
# There are some important correlations here between variables, but none strong enough with the target. Some of the most highliting correlated variables are:
#
# |Features|Interpretation|
# |--------|--------------|
# |income and term| Perfect/Very Strong correlation|
# |property_value and loan_amount| Strong correlation|
# |term and loan_amount| Moderate correlation|
# |income and loan_amount| Moderate correlation|

# %%
# obtain high correlations pairs
def high_corr_pairs(matrix): 
    corr = matrix.abs()
    
    high_corr_pairs = (
        matrix.where(np.triu(np.ones(matrix.shape), k=1).astype(bool))
        .stack()
        .reset_index()
    )
    
    high_corr_pairs = high_corr_pairs[high_corr_pairs[0] > 0.7]
    return high_corr_pairs

high_corr_num_pairs = high_corr_pairs(corr)
high_corr_num_pairs
# Out:
#         level_0         level_1         0
# 4   loan_amount  property_value  0.780522
# 35         term          income  1.000000

# %%
# Check whether they influence in the same proportion to the target. 
def target_influence(matrix):
    unique_values = []
    for col in matrix.columns[0:2]:
        unique_values.extend(matrix[col].unique())
    
    n_vars = len(unique_values)
    n_cols = 2
    n_rows = math.ceil(n_vars/n_cols)
    
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(10, 4*n_rows))
    axes = axes.flatten()
    
    curves = {}
    
    for i, value in enumerate(unique_values):
        print(value)
        curves[value] = df_no_na.groupby(
            pd.qcut(df_no_na[value], 4, duplicates="drop"), 
            observed=True
            )["Status"].mean()
        
        curve = curves[value]
        x = curve.index.astype(str)
        y = curve.values
    
        ax = axes[i]
        ax.plot(x, y, marker='*')
        ax.set_xlabel(f'Bins of {value}')
        ax.set_ylabel('Mean Status')
        ax.set_title(f'Response curve for {value}')
        ax.tick_params(rotation=45)
        ax.grid(True)
    
    for j in range (i+1, len(axes)):
        fig.delaxes(axes[j])
    
    plt.tight_layout()
    plt.show()

target_influence(high_corr_num_pairs)
# Out:
# loan_amount
# term
# property_value
# income

# %% [markdown]
# Term and income show the same curves, which could mean redundancy. However let's calculate the VIF to see if these two have multicolineality

# %%
# Calculate VIF for income and term. 
def vif_calculate(df):
    X = df
    X_const = add_constant(X)
    
    vif = pd.DataFrame({
        "feature": X_const.columns,
        "VIF": [variance_inflation_factor(X_const.values, i)
                for i in range(X_const.shape[1])]
    })
    
    print(vif)

vif_calculate(df_no_na[['income', 'term']])
# Out:
#   feature        VIF
# 0   const  93.595858
# 1  income   1.448022
# 2    term   1.448022

# %% [markdown]
# Based on the VIF results, income is not being explained by term and term is not being explained by income. Thus there is not relevant multicolineality we can keep both variables.

# %%
# Check for categorical correlation
cat_features = df_no_na.select_dtypes(exclude="number").columns

cramer_matrix = pd.DataFrame(index = cat_features, columns=cat_features)

def cramers_v(x, y):
    contingency = pd.crosstab(x, y)
    chi2, _, _, _ = chi2_contingency(contingency)
    n = contingency.to_numpy().sum()
    r, k = contingency.shape
    return np.sqrt(chi2 / (n * (min(r, k) - 1)))

for f1 in cat_features:
 for f2 in cat_features:
     cramer_matrix.loc[f1, f2] = cramers_v(df_no_na[f1], df_no_na[f2])

cramer_matrix = cramer_matrix.astype(float)
cramer_matrix

# plot correlations
plot_corr(cramer_matrix, "Categorical correlations")

# %%
# Obtain the high correlated pairs
high_corr_cat_pairs = high_corr_pairs(cramer_matrix)
high_corr_cat_pairs
# Out:
#                level_0                    level_1         0
# 60           loan_type     business_or_commercial  1.000000
# 166  construction_type                 Secured_by  0.978256
# 173  construction_type              Security_Type  0.978256
# 188         Secured_by              Security_Type  0.978256
# 204                age  submission_of_application  1.000000

# %% [markdown]
# Redundancy among categorical predictors was assessed using Cramér’s V.
# Pairs with very high association (V > 0.9) were considered categorical multicollinearity.
# No additional multicollinearity metric is required for categorical variables, as strong association already implies redundant information.
# Feature selection decisions were therefore based on interpretability and business relevance.

# %%
# check for disponibility of information. 
# count how many nan each category has. 
unique_values = [v
                 for col in high_corr_cat_pairs.columns[:-1]
                 for v in high_corr_cat_pairs[col].unique()]

for value in unique_values:
    print("\n", df_no_na[value].value_counts())
# Out:
#  loan_type
# type1    69758
# type2    15661
# type3    10595
# Name: count, dtype: int64
#
#  construction_type
# sb    95991
# mh       23
# Name: count, dtype: int64
#
#  Secured_by
# home    95991
# land       23
# Name: count, dtype: int64
#
#  age
# 55-64      24277
# 45-54      21923
# 35-44      17053
# 65-74      16977
# 25-34       8727
# >74         6092
# <25          765
# Missing      200
# Name: count, dtype: int64
#
#  business_or_commercial
# nob/c    80353
# b/c      15661
# Name: count, dtype: int64
#
#  Secured_by
# home    95991
# land       23
# Name: count, dtype: int64
#
#  Security_Type
# direct      95991
# Indriect       23
# Name: count, dtype: int64
#
#  submission_of_application
# to_inst    95814
# Missing      200
# Name: count, dtype: int64

# %% [markdown]
# Based on available information and future insights scope:
# - Delete loan_type, the result is less categories more interpretable information.
# - Delete submission_of_application. It is more insightful to have range of ages.
# - Delete construction_type and secured_by, both of these features have high correlation with security_type.

# %%
# Delete redundant columns
df_no_na.drop(columns=["loan_type", "submission_of_application", "construction_type", "Secured_by"], axis=1, inplace=True)
df_na.drop(columns=["loan_type", "submission_of_application", "construction_type", "Secured_by"], axis=1, inplace=True)
df_no_na.columns
# Out:
# Index(['ID', 'year', 'loan_limit', 'Gender', 'approv_in_adv', 'loan_purpose',
#        'Credit_Worthiness', 'open_credit', 'business_or_commercial',
#        'loan_amount', 'rate_of_interest', 'Interest_rate_spread',
#        'Upfront_charges', 'term', 'Neg_ammortization', 'interest_only',
#        'lump_sum_payment', 'property_value', 'occupancy_type', 'total_units',
#        'income', 'credit_type', 'Credit_Score', 'co-applicant_credit_type',
#        'age', 'LTV', 'Region', 'Security_Type', 'Status', 'dtir1',
#        'rate_of_interest_missing', 'Interest_rate_spread_missing',
#        'Upfront_charges_missing', 'dtir1_missing', 'property_value_missing',
#        'LTV_missing', 'income_missing'],
#       dtype='object')

# %%
# Obtain Categorical features.
cat_features = df_no_na.select_dtypes(exclude="number").columns

# separate binary columns from multicategorical columns for both dfs we have. 
binary_cols = []
multi_cols = []

for col in cat_features:
    if df_no_na[col].nunique() == 2:
        binary_cols.append(col)
    else:
        multi_cols.append(col)

# copy the original dfs. 
num_df_no_na = df_no_na.copy()
num_df_na = df_na.copy()

binary_mappings = {}
# binary encoding 
for col in binary_cols:
    categories = sorted(df_na[col].dropna().unique())
    binary_mappings[col] = {categories[0]: 0, categories[1]: 1}

    num_df_no_na[col] = num_df_no_na[col].map(binary_mappings[col])
    num_df_na[col] = num_df_na[col].map(binary_mappings[col])
    
# one- hot encoding
num_df_no_na = pd.get_dummies(num_df_no_na, columns=multi_cols, drop_first=True)
num_df_na = pd.get_dummies(num_df_na, columns=multi_cols, drop_first=True)

# Ensure the same order between dfs. 
num_df_no_na, num_df_na = num_df_no_na.align(
    num_df_na,
    join="left",
    axis=1,
    fill_value=0
)

# check changes
pd.set_option('display.max_columns', None)
display(num_df_no_na)
num_df_na
# Out:
#             ID  year  Credit_Worthiness  open_credit  business_or_commercial  \
# 0        24890  2019                  0            0                       1
# 1        24891  2019                  0            0                       0
# 2        24892  2019                  0            0                       1
# 6        24896  2019                  0            0                       1
# 7        24897  2019                  0            0                       1
# ...        ...   ...                ...          ...                     ...
# 148661  173551  2019                  0            0                       0
# 148663  173553  2019                  0            0                       0
# 148664  173554  2019                  0            0                       0
# 148665  173555  2019                  0            0                       1
# 148668  173558  2019                  0            0                       1
#
#         loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 0         11.665655             3.990                0.5377          3512.50
# 1         12.238061             3.990                0.5377          3512.50
# 2         12.915342             4.560                0.2000           595.00
# 6         12.755641             4.500                0.9998          5120.00
# 7         12.493133             4.125                0.2975          5609.88
# ...             ...               ...                   ...              ...
# 148661    12.755641             3.990                0.5377          3512.50
# 148663    11.575910             3.990                0.5377          3512.50
# 148664    11.960818             3.990                1.4015          3113.06
# 148665    12.986546             3.125                0.2571          9960.00
# 148668    12.188423             3.500                0.5824          4323.33
#
#           term  interest_only  lump_sum_payment  property_value    income  \
# 0       1740.0              1                 1       11.678448  7.462215
# 1       4980.0              1                 0       12.730804  8.513386
# 2       9480.0              1                 1       13.138239  9.157045
# 6       5040.0              1                 1       12.989976  8.525360
# 7       3780.0              1                 1       12.637858  8.237744
# ...        ...            ...               ...             ...       ...
# 148661  4980.0              1                 1       12.788291  8.513386
# 148663  1860.0              1                 1       12.730804  7.528869
# 148664  4020.0              1                 1       11.970357  8.299286
# 148665  7860.0              1                 1       13.317932  8.969669
# 148668  7140.0              1                 1       12.535380  8.873608
#
#         Credit_Score  co-applicant_credit_type        LTV  Security_Type  \
# 0                758                         0  98.728814              1
# 1                552                         1  75.035511              1
# 2                834                         0  80.019685              1
# 6                860                         1  79.109589              1
# 7                863                         0  86.525974              1
# ...              ...                       ...        ...            ...
# 148661           585                         0  96.787710              1
# 148663           619                         1  75.035511              1
# 148664           859                         1  99.050633              1
# 148665           659                         1  71.792763              1
# 148668           737                         1  70.683453              1
#
#         Status  dtir1  rate_of_interest_missing  Interest_rate_spread_missing  \
# 0            1   45.0                         1                             1
# 1            1   39.0                         1                             1
# 2            0   46.0                         0                             0
# 6            0   44.0                         0                             0
# 7            0   42.0                         0                             0
# ...        ...    ...                       ...                           ...
# 148661       1   39.0                         1                             1
# 148663       1   39.0                         1                             1
# 148664       0   45.0                         0                             0
# 148665       0   48.0                         0                             0
# 148668       0   29.0                         0                             0
#
#         Upfront_charges_missing  dtir1_missing  property_value_missing  \
# 0                             1              0                       0
# 1                             1              1                       1
# 2                             0              0                       0
# 6                             0              0                       0
# 7                             0              0                       0
# ...                         ...            ...                     ...
# 148661                        1              1                       0
# 148663                        1              1                       1
# 148664                        0              0                       0
# 148665                        0              0                       0
# 148668                        0              0                       0
#
#         LTV_missing  income_missing  loan_limit_cf  loan_limit_ncf  \
# 0                 0               0           True           False
# 1                 1               0           True           False
# 2                 0               0           True           False
# 6                 0               0           True           False
# 7                 0               0          False           False
# ...             ...             ...            ...             ...
# 148661            0               1           True           False
# 148663            1               0           True           False
# 148664            0               0           True           False
# 148665            0               0           True           False
# 148668            0               0           True           False
#
#         Gender_Joint  Gender_Male  Gender_Sex Not Available  \
# 0              False        False                      True
# 1              False         True                     False
# 2              False         True                     False
# 6               True        False                     False
# 7              False        False                     False
# ...              ...          ...                       ...
# 148661         False        False                      True
# 148663         False         True                     False
# 148664          True        False                     False
# 148665         False        False                      True
# 148668         False        False                     False
#
#         approv_in_adv_nopre  approv_in_adv_pre  loan_purpose_p1  \
# 0                      True              False             True
# 1                      True              False             True
# 2                     False               True             True
# 6                     False               True            False
# 7                      True              False            False
# ...                     ...                ...              ...
# 148661                 True              False            False
# 148663                 True              False             True
# 148664                 True              False             True
# 148665                 True              False            False
# 148668                 True              False            False
#
#         loan_purpose_p2  loan_purpose_p3  loan_purpose_p4  \
# 0                 False            False            False
# 1                 False            False            False
# 2                 False            False            False
# 6                 False             True            False
# 7                 False            False             True
# ...                 ...              ...              ...
# 148661            False            False             True
# 148663            False            False            False
# 148664            False            False            False
# 148665            False             True            False
# 148668            False            False             True
#
#         Neg_ammortization_neg_amm  Neg_ammortization_not_neg  \
# 0                           False                       True
# 1                           False                       True
# 2                            True                      False
# 6                           False                       True
# 7                           False                       True
# ...                           ...                        ...
# 148661                      False                       True
# 148663                      False                       True
# 148664                      False                       True
# 148665                      False                       True
# 148668                      False                       True
#
#         occupancy_type_pr  occupancy_type_sr  total_units_2U  total_units_3U  \
# 0                    True              False           False           False
# 1                    True              False           False           False
# 2                    True              False           False           False
# 6                    True              False           False           False
# 7                    True              False           False           False
# ...                   ...                ...             ...             ...
# 148661               True              False           False           False
# 148663               True              False           False           False
# 148664               True              False           False           False
# 148665               True              False           False           False
# 148668               True              False           False           False
#
#         total_units_4U  credit_type_CRIF  credit_type_EQUI  credit_type_EXP  \
# 0                False             False             False             True
# 1                False             False              True            False
# 2                False             False             False             True
# 6                False             False             False             True
# 7                False             False             False            False
# ...                ...               ...               ...              ...
# 148661           False             False             False             True
# 148663           False             False              True            False
# 148664           False             False             False             True
# 148665           False             False             False            False
# 148668           False             False             False             True
#
#         age_35-44  age_45-54  age_55-64  age_65-74  age_<25  age_>74  \
# 0           False      False      False      False    False    False
# 1           False      False       True      False    False    False
# 2            True      False      False      False    False    False
# 6           False      False       True      False    False    False
# 7           False      False       True      False    False    False
# ...           ...        ...        ...        ...      ...      ...
# 148661      False      False      False      False    False    False
# 148663      False      False      False      False     True    False
# 148664      False      False      False       True    False    False
# 148665      False      False       True      False    False    False
# 148668      False      False       True      False    False    False
#
#         age_Missing  Region_North-East  Region_central  Region_south
# 0             False              False           False          True
# 1             False              False           False         False
# 2             False              False           False          True
# 6             False              False           False         False
# 7             False              False           False         False
# ...             ...                ...             ...           ...
# 148661        False              False           False          True
# 148663        False              False           False         False
# 148664        False              False            True         False
# 148665        False              False           False          True
# 148668        False              False           False         False
#
# [96014 rows x 58 columns]
#             ID  year  Credit_Worthiness  open_credit  business_or_commercial  \
# 0        24890  2019                  0            0                       1
# 1        24891  2019                  0            0                       0
# 2        24892  2019                  0            0                       1
# 6        24896  2019                  0            0                       1
# 7        24897  2019                  0            0                       1
# ...        ...   ...                ...          ...                     ...
# 148661  173551  2019                  0            0                       0
# 148663  173553  2019                  0            0                       0
# 148664  173554  2019                  0            0                       0
# 148665  173555  2019                  0            0                       1
# 148668  173558  2019                  0            0                       1
#
#         loan_amount  rate_of_interest  Interest_rate_spread  Upfront_charges  \
# 0            116500               NaN                   NaN              NaN
# 1            206500               NaN                   NaN              NaN
# 2            406500             4.560                0.2000           595.00
# 6            346500             4.500                0.9998          5120.00
# 7            266500             4.125                0.2975          5609.88
# ...             ...               ...                   ...              ...
# 148661       346500               NaN                   NaN              NaN
# 148663       106500               NaN                   NaN              NaN
# 148664       156500             3.990                1.4015          3113.06
# 148665       436500             3.125                0.2571          9960.00
# 148668       196500             3.500                0.5824          4323.33
#
#          term  interest_only  lump_sum_payment  property_value  income  \
# 0       360.0              1                 1        118000.0  1740.0
# 1       360.0              1                 0             NaN  4980.0
# 2       360.0              1                 1        508000.0  9480.0
# 6       360.0              1                 1        438000.0  5040.0
# 7       360.0              1                 1        308000.0  3780.0
# ...       ...            ...               ...             ...     ...
# 148661  360.0              1                 1        358000.0     NaN
# 148663  360.0              1                 1             NaN  1860.0
# 148664  360.0              1                 1        158000.0  4020.0
# 148665  180.0              1                 1        608000.0  7860.0
# 148668  180.0              1                 1        278000.0  7140.0
#
#         Credit_Score  co-applicant_credit_type        LTV  Security_Type  \
# 0                758                         0  98.728814              1
# 1                552                         1        NaN              1
# 2                834                         0  80.019685              1
# 6                860                         1  79.109589              1
# 7                863                         0  86.525974              1
# ...              ...                       ...        ...            ...
# 148661           585                         0  96.787710              1
# 148663           619                         1        NaN              1
# 148664           859                         1  99.050633              1
# 148665           659                         1  71.792763              1
# 148668           737                         1  70.683453              1
#
#         Status  dtir1  rate_of_interest_missing  Interest_rate_spread_missing  \
# 0            1   45.0                         1                             1
# 1            1    NaN                         1                             1
# 2            0   46.0                         0                             0
# 6            0   44.0                         0                             0
# 7            0   42.0                         0                             0
# ...        ...    ...                       ...                           ...
# 148661       1    NaN                         1                             1
# 148663       1    NaN                         1                             1
# 148664       0   45.0                         0                             0
# 148665       0   48.0                         0                             0
# 148668       0   29.0                         0                             0
#
#         Upfront_charges_missing  dtir1_missing  property_value_missing  \
# 0                             1              0                       0
# 1                             1              1                       1
# 2                             0              0                       0
# 6                             0              0                       0
# 7                             0              0                       0
# ...                         ...            ...                     ...
# 148661                        1              1                       0
# 148663                        1              1                       1
# 148664                        0              0                       0
# 148665                        0              0                       0
# 148668                        0              0                       0
#
#         LTV_missing  income_missing  loan_limit_cf  loan_limit_ncf  \
# 0                 0               0              0           False
# 1                 1               0              0           False
# 2                 0               0              0           False
# 6                 0               0              0           False
# 7                 0               0              0           False
# ...             ...             ...            ...             ...
# 148661            0               1              0           False
# 148663            1               0              0           False
# 148664            0               0              0           False
# 148665            0               0              0           False
# 148668            0               0              0           False
#
#         Gender_Joint  Gender_Male  Gender_Sex Not Available  \
# 0              False        False                      True
# 1              False         True                     False
# 2              False         True                     False
# 6               True        False                     False
# 7              False        False                     False
# ...              ...          ...                       ...
# 148661         False        False                      True
# 148663         False         True                     False
# 148664          True        False                     False
# 148665         False        False                      True
# 148668         False        False                     False
#
#         approv_in_adv_nopre  approv_in_adv_pre  loan_purpose_p1  \
# 0                         0              False                0
# 1                         0              False                0
# 2                         0               True                0
# 6                         0               True                0
# 7                         0              False                0
# ...                     ...                ...              ...
# 148661                    0              False                0
# 148663                    0              False                0
# 148664                    0              False                0
# 148665                    0              False                0
# 148668                    0              False                0
#
#         loan_purpose_p2  loan_purpose_p3  loan_purpose_p4  \
# 0                 False            False            False
# 1                 False            False            False
# 2                 False            False            False
# 6                 False             True            False
# 7                 False            False             True
# ...                 ...              ...              ...
# 148661            False            False             True
# 148663            False            False            False
# 148664            False            False            False
# 148665            False             True            False
# 148668            False            False             True
#
#         Neg_ammortization_neg_amm  Neg_ammortization_not_neg  \
# 0                               0                       True
# 1                               0                       True
# 2                               0                      False
# 6                               0                       True
# 7                               0                       True
# ...                           ...                        ...
# 148661                          0                       True
# 148663                          0                       True
# 148664                          0                       True
# 148665                          0                       True
# 148668                          0                       True
#
#         occupancy_type_pr  occupancy_type_sr  total_units_2U  total_units_3U  \
# 0                    True              False           False           False
# 1                    True              False           False           False
# 2                    True              False           False           False
# 6                    True              False           False           False
# 7                    True              False           False           False
# ...                   ...                ...             ...             ...
# 148661               True              False           False           False
# 148663               True              False           False           False
# 148664               True              False           False           False
# 148665               True              False           False           False
# 148668               True              False           False           False
#
#         total_units_4U  credit_type_CRIF  credit_type_EQUI  credit_type_EXP  \
# 0                False             False             False             True
# 1                False             False              True            False
# 2                False             False             False             True
# 6                False             False             False             True
# 7                False             False             False            False
# ...                ...               ...               ...              ...
# 148661           False             False             False             True
# 148663           False             False              True            False
# 148664           False             False             False             True
# 148665           False             False             False            False
# 148668           False             False             False             True
#
#         age_35-44  age_45-54  age_55-64  age_65-74  age_<25  age_>74  \
# 0           False      False      False      False    False    False
# 1           False      False       True      False    False    False
# 2            True      False      False      False    False    False
# 6           False      False       True      False    False    False
# 7           False      False       True      False    False    False
# ...           ...        ...        ...        ...      ...      ...
# 148661      False      False      False      False    False    False
# 148663      False      False      False      False     True    False
# 148664      False      False      False       True    False    False
# 148665      False      False       True      False    False    False
# 148668      False      False       True      False    False    False
#
#         age_Missing  Region_North-East  Region_central  Region_south
# 0                 0              False           False          True
# 1                 0              False           False         False
# 2                 0              False           False          True
# 6                 0              False           False         False
# 7                 0              False           False         False
# ...             ...                ...             ...           ...
# 148661            0              False           False          True
# 148663            0              False           False         False
# 148664            0              False            True         False
# 148665            0              False           False          True
# 148668            0              False           False         False
#
# [96014 rows x 58 columns]

# %%
# check columns order.
num_df_no_na.columns
num_df_na.columns

# move status at the end of dataframe. 
num_df_no_na["Status"] = num_df_no_na.pop("Status")
num_df_no_na.columns

num_df_na["Status"] = num_df_na.pop("Status")
num_df_na.columns
# Out:
# Index(['ID', 'year', 'Credit_Worthiness', 'open_credit',
#        'business_or_commercial', 'loan_amount', 'rate_of_interest',
#        'Interest_rate_spread', 'Upfront_charges', 'term', 'interest_only',
#        'lump_sum_payment', 'property_value', 'income', 'Credit_Score',
#        'co-applicant_credit_type', 'LTV', 'Security_Type', 'dtir1',
#        'rate_of_interest_missing', 'Interest_rate_spread_missing',
#        'Upfront_charges_missing', 'dtir1_missing', 'property_value_missing',
#        'LTV_missing', 'income_missing', 'loan_limit_cf', 'loan_limit_ncf',
#        'Gender_Joint', 'Gender_Male', 'Gender_Sex Not Available',
#        'approv_in_adv_nopre', 'approv_in_adv_pre', 'loan_purpose_p1',
#        'loan_purpose_p2', 'loan_purpose_p3', 'loan_purpose_p4',
#        'Neg_ammortization_neg_amm', 'Neg_ammortization_not_neg',
#        'occupancy_type_pr', 'occupancy_type_sr', 'total_units_2U',
#        'total_units_3U', 'total_units_4U', 'credit_type_CRIF',
#        'credit_type_EQUI', 'credit_type_EXP', 'age_35-44', 'age_45-54',
#        'age_55-64', 'age_65-74', 'age_<25', 'age_>74', 'age_Missing',
#        'Region_North-East', 'Region_central', 'Region_south', 'Status'],
#       dtype='object')

# %%
# Train your model for Logistic regression
# Logistic regressio

# XGBOOST 

# guarda tu modelo para que lo puedas desplegar en gradio. 

# evalúa y compara ambos 

# saca las features que tuvieron mayor importancia para distinguir

# %%
# Which variables distinguish clients that pay vs the ones that don't pay.
